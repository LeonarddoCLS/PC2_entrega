# %% [markdown]
# # PC2
#
# Nombre:Leonarddo Carlos Lopez Solis
#
# Codigo:20232345

# %%
# !pip install openpyxl
import pandas as pd
link='https://github.com/LeonarddoCLS/PC2_entrega/raw/refs/heads/main/HDI%20(1).xlsx'
data=pd.read_excel(link)
data
# Out:
# ...
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                               NaN         NaN                       NaN
# ...

# %%
#Eliminamos las columnas con las que no vamos a trabajar
#Las eliminamos por posición, para una mayor facilidad

data_clean=data.copy()

byeColumns=[data_clean.columns[i] for i in [3,5,7,9,11,12,13,14]]
data_clean.drop(columns=byeColumns, inplace=True)
data_clean
# Out:
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2                Unnamed: 4  \
# 0                               NaN                       NaN
# ...

# %%
#Renombro las columna que voy a utilizar
#Creamos un diccionario

goodNames=['reconocer', 'Country','HDI','Life_expectancy','Expected_years_of_schooling', 'Mean_years_of_schooling', 'GNI_per_capita']
#Creamos el diccionario con nuevos nombres
{old:new for old,new in zip(data_clean.columns,goodNames)}
# Out:
# {'Back': 'reconocer',
#  'Table 1. Human Development Index and its components ': 'Country',
#  'Unnamed: 2': 'HDI',
#  'Unnamed: 4': 'Life_expectancy',
#  'Unnamed: 6': 'Expected_years_of_schooling',
#  'Unnamed: 8': 'Mean_years_of_schooling',
#  'Unnamed: 10': 'GNI_per_capita'}

# %%
#Reemplazmos los nuevos valores
data_clean.rename(columns={old:new for old, new in zip(data_clean.columns, goodNames)}, inplace=True)
data_clean
# Out:
#     reconocer                                            Country  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                                 HDI           Life_expectancy  \
# 0                               NaN                       NaN
# ...

# %%
#ahora eliminamos las filas que no vamos a utilizar
#la fila en donde empiezan los datos es a partir de la 7, eliminamos las primeras filas 6
byeRows=[0,1,2,3,4,5,6]
data_clean.drop(index=byeRows, inplace=True)
data_clean
# Out:
#     reconocer                                            Country    HDI  \
# 7           1                                        Switzerland  0.962
# 8           2                                             Norway  0.961
# 9           3                                            Iceland  0.959
# 10          4                             Hong Kong, China (SAR)  0.952
# 11          5                                          Australia  0.951
# ..        ...                                                ...    ...
# 271       NaN                          Column 2: UNDESA (2022a).    NaN
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...    NaN
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...    NaN
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...    NaN
# 275       NaN  Column 6: Calculated based on data in columns ...    NaN
#
#     Life_expectancy Expected_years_of_schooling Mean_years_of_schooling  \
# ...

# %%
#Elimino las filas que no tienen información completa de los países
data_clean_new=data_clean.copy()
#Para trabajar con regex, necesito transformar mis valores de la columna reconocer a .string
data_clean_new['reconocer'] = data_clean_new['reconocer'].astype(str)
remove_rows=data_clean_new[~data_clean_new.reconocer.str.contains(pat=r'\d',regex=True)]
#guardo la información de los indices de las filas que no trabajaré
remove_rows_index=list(remove_rows.index)
data_clean_new.drop(index=remove_rows_index, inplace=True)
data_clean_new
# Out:
#     reconocer                   Country    HDI Life_expectancy  \
# 7           1               Switzerland  0.962         83.9872
# 8           2                    Norway  0.961         83.2339
# 9           3                   Iceland  0.959         82.6782
# 10          4    Hong Kong, China (SAR)  0.952         85.4734
# 11          5                 Australia  0.951         84.5265
# ..        ...                       ...    ...             ...
# 196       187                   Burundi  0.426         61.6627
# 197       188  Central African Republic  0.404         53.8947
# 198       189                     Niger    0.4         61.5763
# 199       190                      Chad  0.394         52.5254
# 200       191               South Sudan  0.385         54.9752
#
#     Expected_years_of_schooling Mean_years_of_schooling GNI_per_capita
# 7                     16.500299                13.85966    66933.00454
# ...

# %%
#Elmino columna reconocer
data_clean_new.drop(columns=data_clean_new.columns[0], inplace=True)
data_clean_new
# Out:
#                       Country    HDI Life_expectancy  \
# 7                 Switzerland  0.962         83.9872
# 8                      Norway  0.961         83.2339
# 9                     Iceland  0.959         82.6782
# 10     Hong Kong, China (SAR)  0.952         85.4734
# 11                  Australia  0.951         84.5265
# ..                        ...    ...             ...
# 196                   Burundi  0.426         61.6627
# 197  Central African Republic  0.404         53.8947
# 198                     Niger    0.4         61.5763
# 199                      Chad  0.394         52.5254
# 200               South Sudan  0.385         54.9752
#
#     Expected_years_of_schooling Mean_years_of_schooling GNI_per_capita
# 7                     16.500299                13.85966    66933.00454
# 8                       18.1852                13.00363    64660.10622
# 9                     19.163059                13.76717    55782.04981
# ...

# %%
#Reseteo indices
data_clean_new2=data_clean_new.copy()
data_clean_new2.reset_index(drop=True,inplace=True)
data_clean_new2.index=data_clean_new2.index+1
data_clean_new2
# Out:
#                       Country    HDI Life_expectancy  \
# 1                 Switzerland  0.962         83.9872
# 2                      Norway  0.961         83.2339
# 3                     Iceland  0.959         82.6782
# 4      Hong Kong, China (SAR)  0.952         85.4734
# 5                   Australia  0.951         84.5265
# ..                        ...    ...             ...
# 187                   Burundi  0.426         61.6627
# 188  Central African Republic  0.404         53.8947
# 189                     Niger    0.4         61.5763
# 190                      Chad  0.394         52.5254
# 191               South Sudan  0.385         54.9752
#
#     Expected_years_of_schooling Mean_years_of_schooling GNI_per_capita
# 1                     16.500299                13.85966    66933.00454
# 2                       18.1852                13.00363    64660.10622
# 3                     19.163059                13.76717    55782.04981
# ...

# %%
data_clean_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 1 to 191
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      191 non-null    object
#  1   HDI                          191 non-null    object
#  2   Life_expectancy              191 non-null    object
#  3   Expected_years_of_schooling  191 non-null    object
#  4   Mean_years_of_schooling      191 non-null    object
#  5   GNI_per_capita               191 non-null    object
# dtypes: object(6)
# memory usage: 9.1+ KB

# %%
data_clean_new2=data_clean_new2.astype(str)
byeSpaces=lambda x: x.str.strip()
#ya converití todos mis valores a str
data_clean_new2.iloc[:,[0,5]]=data_clean_new2.iloc[:,[0,5]].apply(byeSpaces)
data_clean_new2
# Out:
#                       Country    HDI Life_expectancy  \
# 1                 Switzerland  0.962         83.9872
# 2                      Norway  0.961         83.2339
# 3                     Iceland  0.959         82.6782
# 4      Hong Kong, China (SAR)  0.952         85.4734
# 5                   Australia  0.951         84.5265
# ..                        ...    ...             ...
# 187                   Burundi  0.426         61.6627
# 188  Central African Republic  0.404         53.8947
# 189                     Niger    0.4         61.5763
# 190                      Chad  0.394         52.5254
# 191               South Sudan  0.385         54.9752
#
#     Expected_years_of_schooling Mean_years_of_schooling GNI_per_capita
# 1                   16.50029945             13.85966015    66933.00454
# 2                   18.18519974             13.00362968    64660.10622
# 3                   19.16305923             13.76716995    55782.04981
# ...

# %%
#Me aseguro de que no haya digitos raros en cada columna de valores que transformaré en númericos
data_clean_new2.HDI[~data_clean_new2.HDI.str.contains('^\d+.\d+')]
# Out:
# Series([], Name: HDI, dtype: object)

# %%
data_clean_new2.Life_expectancy[~data_clean_new2.Life_expectancy.str.contains('^\d+.\d+')]
# Out:
# Series([], Name: Life_expectancy, dtype: object)

# %%
data_clean_new2.Expected_years_of_schooling[~data_clean_new2.Expected_years_of_schooling.str.contains('^\d+.\d+')]
# Out:
# Series([], Name: Expected_years_of_schooling, dtype: object)

# %%
data_clean_new2.Mean_years_of_schooling[~data_clean_new2.Mean_years_of_schooling.str.contains('^\d+.\d+')]
# Out:
# Series([], Name: Mean_years_of_schooling, dtype: object)

# %%
data_clean_new2.GNI_per_capita[~data_clean_new2.GNI_per_capita.str.contains('^\d+.\d+')]
# Out:
# Series([], Name: GNI_per_capita, dtype: object)

# %% [markdown]
# Ningun valor tiene coma o algún otro caracter raro por equivocación

# %%
data_clean_new2['HDI']=pd.to_numeric(data_clean_new2.HDI)
data_clean_new2['Life_expectancy']=pd.to_numeric(data_clean_new2.Life_expectancy)
data_clean_new2['Expected_years_of_schooling']=pd.to_numeric(data_clean_new2.Expected_years_of_schooling)
data_clean_new2['Mean_years_of_schooling']=pd.to_numeric(data_clean_new2.Mean_years_of_schooling)
data_clean_new2['GNI_per_capita']=pd.to_numeric(data_clean_new2.GNI_per_capita)
data_clean_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 1 to 191
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      191 non-null    object
#  1   HDI                          191 non-null    float64
#  2   Life_expectancy              191 non-null    float64
#  3   Expected_years_of_schooling  191 non-null    float64
#  4   Mean_years_of_schooling      191 non-null    float64
#  5   GNI_per_capita               191 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 9.1+ KB

# %%
#Verificamos que todos los valores sean coherentes
data_clean_new2.describe()
#Lo son
# Out:
#               HDI  Life_expectancy  Expected_years_of_schooling  \
# count  191.000000        191.00000                   191.000000
# mean     0.720576         71.31286                    13.534658
# std      0.150661          7.64596                     2.923911
# min      0.385000         52.52540                     5.542510
# 25%      0.599500         65.74720                    11.601258
# 50%      0.739000         71.69400                    13.404920
# 75%      0.835000         76.69930                    15.623665
# max      0.962000         85.47340                    21.054590
#
#        Mean_years_of_schooling  GNI_per_capita
# count               191.000000      191.000000
# mean                  8.986916    20249.088223
# std                   3.173693    21825.277076
# min                   2.114962      731.786709
# 25%                   6.251659     4592.919612
# 50%                   9.306864    12306.341000
# 75%                  11.497702    30079.789725
# ...

# %%
#Ahora revisamos la columna country para luego transformarla a strings
data_clean_new2[data_clean_new2.Country.str.contains(r'[^\w\s]')]
#Hay caracteres especiales
# Out:
#                                 Country    HDI  Life_expectancy  \
# 4                Hong Kong, China (SAR)  0.952          85.4734
# 20                  Korea (Republic of)  0.925          83.6978
# 76           Iran (Islamic Republic of)  0.774          73.8749
# 81                Moldova (Republic of)  0.767          68.8459
# 106                 Palestine, State of  0.715          73.4727
# 118    Bolivia (Plurinational State of)  0.692          63.6304
# 120  Venezuela (Bolivarian Republic of)  0.691          70.5536
# 134    Micronesia (Federated States of)  0.628          70.7100
# 140    Lao People's Democratic Republic  0.607          68.0608
# 141                         Timor-Leste  0.607          67.7369
# 144               Eswatini (Kingdom of)  0.597          57.0657
# 159                       Côte d'Ivoire  0.550          58.5983
# 160       Tanzania (United Republic of)  0.549          66.2007
# 177                       Guinea-Bissau  0.483          59.6523
# ...

# %%
data_clean_new2[data_clean_new2.duplicated(subset='Country')]
#No hay países duplicados
# Out:
# Empty DataFrame
# Columns: [Country, HDI, Life_expectancy, Expected_years_of_schooling, Mean_years_of_schooling, GNI_per_capita]
# Index: []

# %%
data_clean_new2[data_clean_new2.Country.str.contains(r"\w*[\u00C0-\u01DA']\w*")]
#Hay países con tildes especiales
# Out:
#                               Country    HDI  Life_expectancy  \
# 48                            Türkiye  0.838          76.0324
# 140  Lao People's Democratic Republic  0.607          68.0608
# 159                     Côte d'Ivoire  0.550          58.5983
#
#      Expected_years_of_schooling  Mean_years_of_schooling  GNI_per_capita
# 48                     18.338221                 8.633140    31032.801060
# 140                    10.136110                 5.374000     7699.579617
# 159                    10.675580                 5.199139     5217.448516

# %%
#!pip install unidecode

# %%
#Para simplicicar analisis, quitamos todos los caracteres especiales
from unidecode import unidecode

data_clean_new2['Country']=data_clean_new2.Country.apply(unidecode)

# %%
#Colocamos en mayúsculas para facilitar análisis posterior
data_clean_new2['Country']=data_clean_new2.Country.str.upper()
data_clean_new2
# Out:
#                       Country    HDI  Life_expectancy  \
# 1                 SWITZERLAND  0.962          83.9872
# 2                      NORWAY  0.961          83.2339
# 3                     ICELAND  0.959          82.6782
# 4      HONG KONG, CHINA (SAR)  0.952          85.4734
# 5                   AUSTRALIA  0.951          84.5265
# ..                        ...    ...              ...
# 187                   BURUNDI  0.426          61.6627
# 188  CENTRAL AFRICAN REPUBLIC  0.404          53.8947
# 189                     NIGER  0.400          61.5763
# 190                      CHAD  0.394          52.5254
# 191               SOUTH SUDAN  0.385          54.9752
#
#      Expected_years_of_schooling  Mean_years_of_schooling  GNI_per_capita
# 1                      16.500299                13.859660    66933.004540
# 2                      18.185200                13.003630    64660.106220
# 3                      19.163059                13.767170    55782.049810
# ...

# %% [markdown]
# Finalmente, creamos una categoría respecto al HDI

# %%
data_clean_new2['HDI_State']=pd.cut(data_clean_new2.HDI,bins=[0,0.25,0.50,0.75,1],labels=['very_bad','bad','good','very_good'],ordered=True)
data_clean_new2
# Out:
#                       Country    HDI  Life_expectancy  \
# 1                 SWITZERLAND  0.962          83.9872
# 2                      NORWAY  0.961          83.2339
# 3                     ICELAND  0.959          82.6782
# 4      HONG KONG, CHINA (SAR)  0.952          85.4734
# 5                   AUSTRALIA  0.951          84.5265
# ..                        ...    ...              ...
# 187                   BURUNDI  0.426          61.6627
# 188  CENTRAL AFRICAN REPUBLIC  0.404          53.8947
# 189                     NIGER  0.400          61.5763
# 190                      CHAD  0.394          52.5254
# 191               SOUTH SUDAN  0.385          54.9752
#
#      Expected_years_of_schooling  Mean_years_of_schooling  GNI_per_capita  \
# 1                      16.500299                13.859660    66933.004540
# 2                      18.185200                13.003630    64660.106220
# 3                      19.163059                13.767170    55782.049810
# ...

# %%
data_clean_new2.to_pickle("data_clean_new2.pkl")
data_Pickle=pd.read_pickle("data_clean_new2.pkl")
data_Pickle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 1 to 191
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      191 non-null    object
#  1   HDI                          191 non-null    float64
#  2   Life_expectancy              191 non-null    float64
#  3   Expected_years_of_schooling  191 non-null    float64
#  4   Mean_years_of_schooling      191 non-null    float64
#  5   GNI_per_capita               191 non-null    float64
#  6   HDI_State                    191 non-null    category
# dtypes: category(1), float64(5), object(1)
# memory usage: 9.3+ KB
